# %% [markdown]
# # Notebook de apoyo EA3
# Este notebook documenta el flujo conceptual: ETL, KMeans, Silhouette y PCA.

# %% [markdown]
# ## Flujo
# 1. Integrar CSV, PostgreSQL y API REST.\n
# 2. Escalar variables con StandardScaler.\n
# 3. Seleccionar K con método del codo.\n
# 4. Entrenar KMeans.\n
# 5. Evaluar con Silhouette Score.\n
# 6. Visualizar con PCA.
